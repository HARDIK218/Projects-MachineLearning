# %% [markdown]
# <a href="https://colab.research.google.com/github/HARDIK218/Projects/blob/main/Amazon_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from tensorflow.keras.layers import (
    Dense,
    Dropout,
    LSTM,
)

# %%
Data = pd.read_csv("/content/drive/MyDrive/data/train.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Data.head(10)
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
# 5     2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 6      413758                      Ungifted: My Life and Journey
# 7     2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# 8     2050239  PUMA Cali Sport Clean Women's Sneakers White L...
# 9     2998633  Hexwell Essential oil for Home Fragrance Oil A...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2249698 entries, 0 to 2249697
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PRODUCT_ID       int64
#  1   TITLE            object
#  2   BULLET_POINTS    object
#  3   DESCRIPTION      object
#  4   PRODUCT_TYPE_ID  int64
#  5   PRODUCT_LENGTH   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 103.0+ MB

# %%
Data.describe()
# Out:
#          PRODUCT_ID  PRODUCT_TYPE_ID  PRODUCT_LENGTH
# count  2.249698e+06     2.249698e+06    2.249698e+06
# mean   1.499795e+06     4.000456e+03    4.071839e+03
# std    8.661944e+05     3.966146e+03    1.351685e+06
# min    1.000000e+00     0.000000e+00    1.000000e+00
# 25%    7.494795e+05     2.300000e+02    5.118110e+02
# 50%    1.499558e+06     2.916000e+03    6.630000e+02
# 75%    2.250664e+06     6.403000e+03    1.062992e+03
# max    2.999999e+06     1.342000e+04    1.885801e+09

# %%
Data.isnull().sum()
# Out:
# PRODUCT_ID               0
# TITLE                   12
# BULLET_POINTS       837364
# DESCRIPTION        1157381
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
Data = Data.drop(columns=['PRODUCT_ID'], axis= 1)

# %%
Data.isnull().sum()
# Out:
# TITLE                   12
# BULLET_POINTS       837364
# DESCRIPTION        1157381
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
Data['DESCRIPTION'] = Data['TITLE'] + " " +  Data['BULLET_POINTS'] + " " + Data['DESCRIPTION']

# %%
Data.sample(10)
# Out:
#                                                      TITLE  \
# 677248   Great Dane Art: Blank Lined Notebook for Dog L...
# 121588   Astronomy by Observation: An Elementary Text-B...
# 2223440                            My teacher, my love t04
# 1326336  Life by Shoppers Stop Womens Checked Casual Sh...
# 1150676            GRG - Mobile Adapter Mount Charging Bag
# 2220770  YEEBAY Upgraded & Stitched Window Mosquito Net...
# 1097579                   The Knight in the Panther's Skin
# 1839588  Dare to Dream: The Art of Co-creating With God...
# 690407   KANSHOK Cotton Bath Towel Full Size (70*140) (...
# 1713633  Balboa Baby Cotton Sateen Dust Ruffle - Pink C...
#
#                                              BULLET_POINTS  \
# 677248                                                 NaN
# 121588                                                 NaN
# 2223440                                                NaN
# 1326336  [Pattern: Checked,Neckline: Collared,Sleeves: ...
# ...

# %%
Data.isnull().sum()
# Out:
# TITLE                   12
# BULLET_POINTS       837364
# DESCRIPTION        1211238
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
Data = Data.dropna(axis = 0)
Data
# Out:
#                                                      TITLE  \
# 2        PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3        ALISHAH Women's Cotton Ankle Length Leggings C...
# 5        HINS Metal Bucket Shape Plant Pot for Indoor &...
# 7        Delavala Self Adhesive Kitchen Backsplash Wall...
# 9        Hexwell Essential oil for Home Fragrance Oil A...
# ...                                                    ...
# 2249686  Cocomii Holographic iPhone 11 Pro Case - Holog...
# 2249689  Have It Tall Men's Curved Hem Long Drop Tail T...
# 2249694  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249697  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# 2        [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3        [Made By 95%cotton and 5% Lycra which gives yo...
# 5        [Simple and elegant, great for displaying indo...
# ...

# %%
Data.duplicated().sum()
Data= Data.drop_duplicates(keep='first')
Data
# Out:
#                                                      TITLE  \
# 2        PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3        ALISHAH Women's Cotton Ankle Length Leggings C...
# 5        HINS Metal Bucket Shape Plant Pot for Indoor &...
# 7        Delavala Self Adhesive Kitchen Backsplash Wall...
# 9        Hexwell Essential oil for Home Fragrance Oil A...
# ...                                                    ...
# 2249686  Cocomii Holographic iPhone 11 Pro Case - Holog...
# 2249689  Have It Tall Men's Curved Hem Long Drop Tail T...
# 2249694  (3PCS) Goose Game Cute Cartoon Enamel Pins, Fu...
# 2249695  Kangroo Sweep Movement Printed Wooden Wall Clo...
# 2249697  Skyjacker C7360SP Component Box For PN[C7360PK...
#
#                                              BULLET_POINTS  \
# 2        [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3        [Made By 95%cotton and 5% Lycra which gives yo...
# 5        [Simple and elegant, great for displaying indo...
# ...

# %%
Data['PRODUCT_TYPE_ID'].value_counts().head(500)
# Out:
# 12064    49911
# 0        19082
# 2879     14652
# 2211     14107
# 2986     13172
#          ...
# 280        351
# 10432      351
# 7314       350
# 10171      349
# 1460       349
# Name: PRODUCT_TYPE_ID, Length: 500, dtype: int64

# %%
Data_new_sample = Data.sample(20000, random_state=2)

# %%
Data.drop(columns = ["TITLE","BULLET_POINTS", "PRODUCT_TYPE_ID"], axis = 1 , inplace = True)
# Out:
# <ipython-input-17-a3495c10238c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data.drop(columns = ["TITLE","BULLET_POINTS", "PRODUCT_TYPE_ID"], axis = 1 , inplace = True)

# %%
Data.shape
# Out:
# (1026255, 2)

# %%
Data_new_sample.drop(columns = ["TITLE","BULLET_POINTS", "PRODUCT_TYPE_ID"], axis = 1 , inplace = True)

# %%
Data_new_sample
# Out:
#                                                DESCRIPTION  PRODUCT_LENGTH
# 1147095  Magic Boy's Denim Shirt, Jeans and Jacket Clot...      354.330708
# 613870   Chippewa Men's 17" Waterproof Pull On 25110 Sn...     2000.000000
# 789956   Visitors Present Sheesham Wooden Salt/Masala/T...      236.220472
# 1181765  Gulp! Alive! Minnow [Each bait has a natural p...      700.000000
# 593812   TravisLappy Laptop Internal Speaker for Sony V...     1377.952755
# ...                                                    ...             ...
# 282561   YaaNaa Printed Ceramic Coffee Mug, May Birthda...      511.811023
# 1012816  Blue Cornflower Petals 1 KG pack of (5) [Natur...      984.251967
# 723760   Mphmi Plants Hari champa, Artabotrys hexapetal...      275.590551
# 140130   FASHEEN Anti Glare Eye Protection Matte Finish...      787.401574
# 754390   GMB 148-1780 OE Replacement Water Pump with Ga...      900.000000
#
# [20000 rows x 2 columns]

# %%
# !pip install tensorflow-text

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from sklearn.metrics.pairwise import cosine_similarity


from sklearn.model_selection import train_test_split

# %%
encoder_url  = 'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4'
preprocess_url = 'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3'

# %%
bert_preprocess_model = hub.KerasLayer(preprocess_url)
bert_encoder = hub.KerasLayer(encoder_url)

# %%
def get_embeddings(sentence):
  preprocessed_text = encoder_url(sentence)
  embedding = preprocess_url(preprocessed_text)['pooled_output']

# %%
# Bert Layers
input_layer = tf.keras.layers.Input(shape = (),dtype = tf.string, name = 'Input')
preprocessed_text = bert_preprocess_model(input_layer)
output =  bert_encoder(preprocessed_text)

# %%
output_1 = tf.keras.layers.Dropout(0.1, name = 'dropout')(output['pooled_output'])

output_cat = tf.keras.layers.Dense(1, activation = 'relu', name = 'category')(output_1)

# %%
# Experiment using lstm layer
output_1 = tf.keras.layers.Dropout(0.1, name = 'dropout')(output['pooled_output'])
output_1 = tf.keras.layers.Reshape((1, 768))(output_1)

output_2 = tf.keras.layers.LSTM(64, input_shape=(None, 768))(output_1)

output_cat = tf.keras.layers.Dense(1, activation='linear', name='category')(output_2)

# %%
x_train, x_test, y_train, y_test = train_test_split(Data_new_sample['DESCRIPTION'], Data_new_sample['PRODUCT_LENGTH'], test_size = 0.25, random_state = 5)

# %%
model =tf.keras.Model(inputs = [input_layer], outputs = [output_cat])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  Input (InputLayer)          [(None,)]                    0         []
#
#  keras_layer (KerasLayer)    {'input_type_ids': (None,    0         ['Input[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  keras_layer_1 (KerasLayer)  {'sequence_output': (None,   1094822   ['keras_layer[0][0]',
#                               128, 768),                  41         'keras_layer[0][1]',
#                               'default': (None, 768),                'keras_layer[0][2]']
#                               'pooled_output': (None, 7
#                              68),
#                               'encoder_outputs': [(None
# ...

# %%
tf.keras.metrics.MeanSquaredError(name="mean_squared_error", dtype=None)

# %%
tf.keras.optimizers.Adam(
    learning_rate=0.1,
    name = 'adam'

)

# %%
tf.keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")

# %%
model.compile(optimizer = 'adam', loss=tf.keras.losses.MeanSquaredError(), metrics =tf.keras.metrics.MeanSquaredError())

# %%
model.fit(x_train, y_train, epochs = 10, validation_data = [x_test, y_test])
# Out:
# Epoch 1/10
# 469/469 [==============================] - 236s 503ms/step - loss: 6843776512.0000 - mean_squared_error: 6843776512.0000 - val_loss: 401529856.0000 - val_mean_squared_error: 401529856.0000
# Epoch 2/10
# 469/469 [==============================] - 256s 547ms/step - loss: 6843751424.0000 - mean_squared_error: 6843751424.0000 - val_loss: 401515968.0000 - val_mean_squared_error: 401515968.0000
# Epoch 3/10
# 469/469 [==============================] - 232s 494ms/step - loss: 6843735040.0000 - mean_squared_error: 6843735040.0000 - val_loss: 401500224.0000 - val_mean_squared_error: 401500224.0000
# Epoch 4/10
# 469/469 [==============================] - 256s 547ms/step - loss: 6843712512.0000 - mean_squared_error: 6843712512.0000 - val_loss: 401484192.0000 - val_mean_squared_error: 401484192.0000
# Epoch 5/10
# ...
